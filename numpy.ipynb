# %%
import numpy as np

# %%
np.array([1,2,3,4,4,55,65,65])
# Out:
# array([ 1,  2,  3,  4,  4, 55, 65, 65])

# %%
a=np.array([1,3,4,56,324,676,7878,787])
b=np.array([21,43,54,565,76,688,686])
#print certain[] in the array
print(a[1],b[2])
# print whole array
print(a,b)
# Out:
# 3 54

# %%
a[1:2]
# Out:
# array([3])

# %%
a[::2]
# Out:
# array([   1,    4,  324, 7878])

# %%
##  can not pass  too may array 
a[2,3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 a[2,3]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
## have to pass list in a list [  []  ]

a[[2,3]]
# Out:
# array([ 4, 56])

# %%
a[1],a[3]
# Out:
# (3, 56)

# %%
b[1],b[5],b[3]
# Out:
# (43, 688, 565)

# %%
## index 8 is not  avilable
b[[6,5,8]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 b[[6,5,8]]
#
# IndexError: index 8 is out of bounds for axis 0 with size 7

# %%
# type of array

a.dtype
# Out:
# dtype('int32')

# %%
b.dtype
# Out:
# dtype('int32')

# %%
## you can change  array using numpy into float

np.array([23,34,54,87,57],dtype=np.float64)
# Out:
# array([23., 34., 54., 87., 57.])

# %% [markdown]
# ##   multidimensional array  (have more than 1 rows and column in the matrix)

# %%
A=np.array(([2,3,4],
        [34,56,67]   ) )
print(A)
# Out:
# [[ 2  3  4]
#  [34 56 67]]

# %%
A.shape ## 2 rows and 3 columns
# Out:
# (2, 3)

# %%
A.size  ##total numbers in the array
# Out:
# 6

# %%
A.ndim   ## 2 set of matrix
# Out:
# 2

# %%
B=np.array([
   [ [[244,563,664],
        [314,526,67]],
            
            [[23,56,67],
             [23,34,56]]]
    ])
print(B)
# Out:
# [[[[244 563 664]
#    [314 526  67]]
#
#   [[ 23  56  67]
#    [ 23  34  56]]]]

# %%
B.ndim
# Out:
# 4

# %%
B.size
# Out:
# 12

# %%
B.shape
# Out:
# (1, 2, 2, 3)

# %%
##indexing  and slicing
c=np.array([
#    0,1,2
    [1,2,3],    #0
    [5,6,67],   #1
    [32,45,65]  #2
    
   ])
print(c)
# Out:
# [[ 1  2  3]
#  [ 5  6 67]
#  [32 45 65]]

# %%
c[1]
# Out:
# array([ 5,  6, 67])

# %%
c[0:1]
# Out:
# array([[1, 2, 3]])

# %%
c[0:2]
# Out:
# array([[ 1,  2,  3],
#        [ 5,  6, 67]])

# %%
c[0]= np.array([12,12,12])
print(c)
# Out:
# [[12 12 12]
#  [ 5  6 67]
#  [32 45 65]]

# %%
c[2]=99

# %%
c
# Out:
# array([[12, 12, 12],
#        [ 5,  6, 67],
#        [99, 99, 99]])

# %%
c.mean()
# Out:
# 45.666666666666664

# %%
c.std()
# Out:
# 41.65466493816882

# %%
c.sum()
# Out:
# 411

# %%
##  12+12+12=36
## 5+6+67= 78
## 99+99+99 =297

c.sum(axis=1)
# Out:
# array([ 36,  78, 297])

# %%
##   12+5+99=116
##   12+6+99 =117
## 12+67+99 =178

c.sum(axis=0)
# Out:
# array([116, 117, 178])

# %%
c.mean(axis=0)
# Out:
# array([38.66666667, 39.        , 59.33333333])

# %%
c.std(axis=0)
# Out:
# array([42.75771535, 42.49705872, 35.92894222])

# %%
c.std(axis=1)
# Out:
# array([ 0.       , 28.9942523,  0.       ])
